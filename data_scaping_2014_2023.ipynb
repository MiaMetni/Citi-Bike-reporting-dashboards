# %%
## PRELIM STEP: refine, organize, and merge data

# %%
# Import Dependencies
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Store filepaths for 2014 into variables
jan_2014_csv = Path("Resources/2014-citibike-tripdata/1_January/201401-citibike-tripdata_1.csv")
feb_2014_csv = Path("Resources/2014-citibike-tripdata/2_February/201402-citibike-tripdata_1.csv")
mar_2014_csv = Path("Resources/2014-citibike-tripdata/3_March/201403-citibike-tripdata_1.csv")
apr_2014_csv = Path("Resources/2014-citibike-tripdata/4_April/201404-citibike-tripdata_1.csv")
may_2014_csv = Path("Resources/2014-citibike-tripdata/5_May/201405-citibike-tripdata_1.csv")
jun_2014_csv = Path("Resources/2014-citibike-tripdata/6_June/201406-citibike-tripdata_1.csv")
jul_2014_csv = Path("Resources/2014-citibike-tripdata/7_July/201407-citibike-tripdata_1.csv")
aug_2014_csv = Path("Resources/2014-citibike-tripdata/8_August/201408-citibike-tripdata_1.csv")
sep_2014_csv = Path("Resources/2014-citibike-tripdata/9_September/201409-citibike-tripdata_1.csv") 
oct_2014_csv = Path("Resources/2014-citibike-tripdata/10_October/201410-citibike-tripdata_1.csv")
nov_2014_csv = Path("Resources/2014-citibike-tripdata/11_November/201411-citibike-tripdata_1.csv")
dec_2014_csv = Path("Resources/2014-citibike-tripdata/12_December/201412-citibike-tripdata_1.csv")

# Store filepaths for 2023 into variables
    #note, customer type for 2023 data uses member vs casual instead of subscrfiber vs customer (make this change later in df cleaning)
jan_2023_csv = Path("Resources/2023-citibike-tripdata/1_January/202301-citibike-tripdata_1.csv")
feb_2023_csv = Path("Resources/2023-citibike-tripdata/2_February/202302-citibike-tripdata_1.csv")
mar_2023_csv = Path("Resources/2023-citibike-tripdata/3_March/202303-citibike-tripdata_1.csv")
apr_2023_csv = Path("Resources/2023-citibike-tripdata/4_April/202304-citibike-tripdata_1.csv")
may_2023_csv = Path("Resources/2023-citibike-tripdata/5_May/202305-citibike-tripdata_1.csv")
jun_2023_csv = Path("Resources/2023-citibike-tripdata/6_June/202306-citibike-tripdata_1.csv")
jul_2023_csv = Path("Resources/2023-citibike-tripdata/7_July/202307-citibike-tripdata_1.csv")
aug_2023_csv = Path("Resources/2023-citibike-tripdata/8_August/202308-citibike-tripdata_1.csv")
sep_2023_csv = Path("Resources/2023-citibike-tripdata/9_September/202309-citibike-tripdata_1.csv") 
oct_2023_csv = Path("Resources/2023-citibike-tripdata/10_October/202310-citibike-tripdata_1.csv")
nov_2023_csv = Path("Resources/2023-citibike-tripdata/11_November/202311-citibike-tripdata_1.csv")
dec_2023_csv = Path("Resources/2023-citibike-tripdata/12_December/202312-citibike-tripdata_1.csv")

# %%
# Read in files and make dfs for 2014 data
jan_2014_df = pd.read_csv(jan_2014_csv)
feb_2014_df = pd.read_csv(feb_2014_csv)
mar_2014_df = pd.read_csv(mar_2014_csv)
apr_2014_df = pd.read_csv(apr_2014_csv)
may_2014_df = pd.read_csv(may_2014_csv)
jun_2014_df = pd.read_csv(jun_2014_csv)
jul_2014_df = pd.read_csv(jul_2014_csv)
aug_2014_df = pd.read_csv(aug_2014_csv)
sep_2014_df = pd.read_csv(sep_2014_csv)
oct_2014_df = pd.read_csv(oct_2014_csv)
nov_2014_df = pd.read_csv(nov_2014_csv)
dec_2014_df = pd.read_csv(dec_2014_csv)

# Read data for 2023 into DataFrames with specified data types for columns 5 and 7 as strings
jan_2023_df = pd.read_csv(jan_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
feb_2023_df = pd.read_csv(feb_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
mar_2023_df = pd.read_csv(mar_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
apr_2023_df = pd.read_csv(apr_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
may_2023_df = pd.read_csv(may_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
jun_2023_df = pd.read_csv(jun_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
jul_2023_df = pd.read_csv(jul_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
aug_2023_df = pd.read_csv(aug_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
sep_2023_df = pd.read_csv(sep_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
oct_2023_df = pd.read_csv(oct_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
nov_2023_df = pd.read_csv(nov_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)
dec_2023_df = pd.read_csv(dec_2023_csv, dtype={'start_station_name': 'str', 'end_station_name': 'str'}, low_memory=False)

# %%
# Merge the data for each year
merged_2014_df = pd.concat([jan_2014_df, feb_2014_df, mar_2014_df, apr_2014_df, may_2014_df, jun_2014_df, 
                            jul_2014_df, aug_2014_df, sep_2014_df, oct_2014_df, nov_2014_df, dec_2014_df])

merged_2023_df = pd.concat([jan_2023_df, feb_2023_df, mar_2023_df, apr_2023_df, may_2023_df, jun_2023_df, 
                            jul_2023_df, aug_2023_df, sep_2023_df, oct_2023_df, nov_2023_df, dec_2023_df])

# %%
#display
display(merged_2014_df)
display(merged_2023_df)
# Out:
#         tripduration            starttime             stoptime  \
# 0                471  2014-01-01 00:00:06  2014-01-01 00:07:57
# 1               1494  2014-01-01 00:00:38  2014-01-01 00:25:32
# 2                464  2014-01-01 00:03:59  2014-01-01 00:11:43
# 3                373  2014-01-01 00:05:15  2014-01-01 00:11:28
# 4                660  2014-01-01 00:05:18  2014-01-01 00:16:18
# ...              ...                  ...                  ...
# 399064           553  12/31/2014 23:55:22    1/1/2015 00:04:35
# 399065          1355  12/31/2014 23:56:37    1/1/2015 00:19:12
# 399066           431  12/31/2014 23:57:03    1/1/2015 00:04:14
# 399067           332  12/31/2014 23:57:25    1/1/2015 00:02:57
# 399068          2048  12/31/2014 23:58:16    1/1/2015 00:32:24
#
#         start station id             start station name  \
# 0                   2009       Catherine St & Monroe St
# 1                    536                1 Ave & E 30 St
# ...

# %%
# make column name variables constant throughout dfs
merged_2014_df.rename(columns)
